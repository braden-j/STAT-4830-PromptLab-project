# %% [markdown]
# # Tournament Preflight
#
# Install the tournament dependencies, export `HF_TOKEN` and `WANDB_API_KEY`, then run the shared auth verifier.

# %%
# %pip install -e .[tournament]
# !python tournament/scripts/verify_access.py
