# %% [markdown]
# # Evaluate and Rank Checkpoints
#
# Run shared checkpoint evaluation, then aggregate multiple summary JSON files into a leaderboard CSV.

# %%
# %pip install -e .[tournament]
# !python tournament/scripts/eval_checkpoint.py --config tournament/configs/eval/leaderboard.yaml
# !python tournament/scripts/eval_leaderboard.py --eval-json tournament/outputs/leaderboards/m2_eval.json
