# %% [markdown]
# # Train SFT Entrants
#
# Choose one of the `M1`-`M6` configs and run it through the shared `train_sft.py` entrypoint.

# %%
# %pip install -e .[tournament]
# !python tournament/scripts/train_sft.py --config tournament/configs/train/m2_full_lora.yaml
