# %% [markdown]
# # Train the DPO Entrant
#
# Build `P3` first, then call the shared DPO training entrypoint.

# %%
# %pip install -e .[tournament]
# !python tournament/scripts/build_p3_preferences.py
# !python tournament/scripts/train_dpo.py --config tournament/configs/train/m7_dpo.yaml
